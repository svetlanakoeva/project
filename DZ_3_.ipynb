# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace (-2*np.pi, 3*np.pi, 201)
plt.plot(x, 3 * np.cos(x - 1) -1)
plt.plot(x, 2 * np.cos(x - 2) +1)
plt.xlabel('x')
plt.xlabel('y')
plt.grid(True)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 x = np.linspace (-1, 3, 201)
#       2 plt.plot(x, x**3 -4*x**2 + 5*x-2)
#       3 plt.xlabel('x')
#
# NameError: name 'np' is not defined
